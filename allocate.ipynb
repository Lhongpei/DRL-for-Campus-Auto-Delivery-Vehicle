# %%
from code.alloc_veh import AllocVeh
from code.utils import rand_create_Boxes, rand_gener_map

# %%
boxes= rand_create_Boxes([13,19],20,10)
locs = rand_gener_map(100, 20)
init_point = 15
velocity = velocity = [[1 for i in range(20)] for i in range(20)]
alloc_class = AllocVeh(init_point, locs, boxes, velocity)
alloc_class.construct_model()
alloc_class.solve(False)
alloc_class.draw_locations_opt()
# Out:
# Cardinal Optimizer v7.0.6. Build date Jan 16 2024
# Copyright Cardinal Operations 2023. All Rights Reserved
#
# Initializing model, 20 locations and 2 boxes
# Model constructed successfully
# Model fingerprint: 47965157
#
# Using Cardinal Optimizer v7.0.6 on Linux
# Hardware has 96 cores and 192 threads. Using instruction set X86_AVX512_E1 (14)
# Minimizing a MIP problem
#
# The original problem has:
#     679 rows, 402 columns and 14020 non-zero elements
#     402 binaries
#
# Presolving the problem
#
# The presolved problem has:
#     591 rows, 71 columns and 8211 non-zero elements
#     71 binaries
#
# Starting the MIP solver with 32 threads and 64 tasks
#
#      Nodes    Active  LPit/n  IntInf     BestBound  BestSolution    Gap   Time
#          0         1      --       0  0.000000e+00            --    Inf  0.11s
# H        0         1      --       0  0.000000e+00  1.001696e+07 100.0%  0.11s
#          0         1      --      14  7.506266e+06  1.001696e+07  25.1%  0.20s
#          0         1      --      14  7.506266e+06  1.001696e+07  25.1%  0.22s
#          1         0     0.0      14  1.001696e+07  1.001696e+07  0.00%  0.26s
#          1         0     0.0      14  1.001696e+07  1.001696e+07  0.00%  0.27s
#
# Best solution   : 10016962.946529549
# Best bound      : 10016962.946529549
# Best gap        : 0.0000%
# Solve time      : 0.27
# Solve node      : 1
# MIP status      : solved
# Solution status : integer optimal (relative gap limit 0.0001)
#
# Violations      :     absolute     relative
#   bounds        :            0            0
#   rows          :            0            0
#   integrality   :            0
# Model solved
